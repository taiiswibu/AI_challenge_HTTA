# %% [markdown]
# # 1. ket noi sql va tao duong dan
# # ket noi moi dung duoc nha

# %%
import os
import psycopg2
import pandas as pd
from PIL import Image
import torch
from transformers import CLIPProcessor, CLIPModel
from pymilvus import connections, Collection

# ================== Config ==================
DB_PARAMS = {
    "dbname": "video_db",   # database đã tạo
    "user": "postgres",
    "password": "123",      # đổi theo mật khẩu của bạn
    "host": "localhost",
    "port": "5432"
}

CSV_DIR   = "/home/shared/data_batch1/map-keyframes/"  # file CSV mapping cho mỗi video
FRAME_DIR = "/home/shared/data_batch1/Keyframes/"      # thư mục chứa nhiều nhóm + nhiều anh con
VIDEO_DIR = "/home/shared/data_batch1/Videos/"         # thư mục chứa video

MODEL_DIR = "/home/shared/huggingface_cache"  # nơi lưu model CLIP

# ================== Kết nối DB ==================
conn = psycopg2.connect(**DB_PARAMS)
cur = conn.cursor()

# ================== Kết nối Milvus ==================
connections.connect(alias="default", host='localhost', port='19530')

# ================== Load CLIP model CPU ==================
device = "cpu"
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32", cache_dir=MODEL_DIR).to(device)
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32", cache_dir=MODEL_DIR)

# %%
from pymilvus import connections
print(connections.list_connections())
# Out:
# [('default', <pymilvus.client.grpc_handler.GrpcHandler object at 0x7cee60794a50>)]

# %%
from pymilvus import Collection

collection = Collection("text_image_video_collection")
print("Số lượng bản ghi hiện tại:", collection.num_entities)
# Out:
# Số lượng bản ghi hiện tại: 177321

# %%
from pymilvus import Collection

# load collection
collection = Collection("text_image_video_collection")

# In schema ra để xem các field
print(collection.schema)

# Hoặc in chi tiết từng field
for field in collection.schema.fields:
    print("Field name:", field.name, "| Type:", field.dtype, "| Desc:", field.description)
# Out:
# {'auto_id': True, 'description': '', 'fields': [{'name': 'id', 'description': '', 'type': <DataType.INT64: 5>, 'is_primary': True, 'auto_id': True}, {'name': 'vector', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 512}}], 'enable_dynamic_field': True}
# Field name: id | Type: 5 | Desc:
# Field name: vector | Type: 101 | Desc:

# %% [markdown]
# # 2. tao conlection (chay 1 lan)
# # khong chay o day

# %%
from pymilvus import MilvusClient
# Kết nối Milvus
milvus_client = MilvusClient(uri="http://localhost:19530")

# Tên collection
collection_name = "text_image_video_collection"

# Xóa collection cũ (nếu có) -> khởi tạo lại từ đầu
# if milvus_client.has_collection(collection_name):
#     milvus_client.drop_collection(collection_name)
#     print(f"⚠️ Collection '{collection_name}' đã bị xóa") # vay cho chac

# Tạo collection mới
milvus_client.create_collection(
    collection_name=collection_name,
    dimension=512,              # Vector size của CLIP ViT-B/32
    auto_id=True,               # Tự động tạo ID
    enable_dynamic_field=True   # Cho phép thêm field động (vd: frame_path)
)

# Kiểm tra danh sách collection hiện có
collections = milvus_client.list_collections()
print("✅ Danh sách collection:", collections) # dung chay, mat het data do
# Out:
# ⚠️ Collection 'text_image_video_collection' đã bị xóa
# ✅ Danh sách collection: ['image_collection', 'text_image_video_collection']

# %% [markdown]
# # 3. Load CLIP model (run cai nay khi can query)

# %%
import torch
from PIL import Image
from transformers import CLIPModel, CLIPProcessor

# Chỉ dùng CPU
device = torch.device("cpu")

# Tải mô hình CLIP đã huấn luyện trước từ Hugging Face, lưu tại MODEL_DIR
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32", cache_dir=MODEL_DIR).to(device)

# Tải processor của CLIP
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32", cache_dir=MODEL_DIR)

def encode_image(image_path):
    """
    Mã hóa hình ảnh thành vector đặc trưng bằng CLIP trên CPU.
    """
    try:
        image = Image.open(image_path)
        inputs = processor(images=image, return_tensors="pt").to(device)
        with torch.no_grad():
            image_features = model.get_image_features(**inputs)
        return image_features[0].cpu().numpy()
    except Exception as e:
        print(f"Lỗi khi xử lý {image_path}: {e}")
        return None

# %% [markdown]
# # Hàm insert tách riêng (chay roi khong can chay nua)

# %%
# ================== Hàm insert vào Milvus 3.x ==================
def insert_to_milvus(frame_path, emb):
    """
    Chèn vector đặc trưng và đường dẫn frame vào collection trong Milvus 3.x.

    Args:
        frame_path (str): Đường dẫn tới file frame (hình ảnh).
        emb (numpy.ndarray): Vector đặc trưng của frame (thường từ mô hình như CLIP).

    Returns:
        str: ID của bản ghi vừa chèn trong Milvus, hoặc None nếu lỗi.
    """
    try:
        # Chèn dữ liệu vào collection đã tạo
        res = milvus_client.insert(
            collection_name=collection_name,
            data=[{"vector": emb.tolist(), "frame_path": frame_path}]
        )
        # Trả về ID đầu tiên nếu có
        return res["ids"][0] if "ids" in res and len(res["ids"]) > 0 else None

    except Exception as e:
        print(f"❌ Lỗi insert Milvus cho {frame_path}: {e}")
        return None


# ================== Hàm insert vào PostgreSQL ==================
def insert_to_postgres(video_id, frame_path, pts_time, frame_idx, fps, milvus_id):
    """
    Chèn thông tin frame vào bảng frame_mappings trong PostgreSQL.

    Args:
        video_id (str): ID của video chứa frame.
        frame_path (str): Đường dẫn tới file frame.
        pts_time (float): Thời gian trình bày (presentation timestamp) của frame trong video.
        frame_idx (int): Chỉ số của frame trong video.
        fps (float): Tốc độ khung hình (frames per second) của video.
        milvus_id (str): ID của bản ghi tương ứng trong Milvus.

    Returns:
        None
    """
    try:
        cur.execute("""
            INSERT INTO frame_mappings (video_id, frame_path, pts_time, frame_idx, fps, milvus_id)
            VALUES (%s, %s, %s, %s, %s, %s)
            ON CONFLICT (frame_path) DO NOTHING
        """, (video_id, frame_path, pts_time, frame_idx, fps, milvus_id))
        conn.commit()  # commit ngay sau insert
    except Exception as e:
        print(f"❌ Lỗi insert Postgres cho {frame_path}: {e}")

# %% [markdown]
# # Cell 6 – Index toàn bộ video (dùng khi mới chạy lần đầu hoặc re-index)

# %%
# ================== Cell 6: Index dữ liệu ==================
def insert_to_milvus(frame_path, emb):
    """
    Chèn vector đặc trưng và đường dẫn frame vào collection Milvus 3.x.
    """
    try:
        res = milvus_client.insert(
            collection_name=collection_name,
            data=[{"vector": emb.tolist(), "frame_path": frame_path}]
        )
        return res["ids"][0] if "ids" in res and len(res["ids"]) > 0 else None
    except Exception as e:
        print(f"❌ Lỗi insert Milvus cho {frame_path}: {e}")
        return None

def insert_to_postgres(video_id, frame_path, pts_time, frame_idx, fps, milvus_id):
    """
    Chèn metadata của frame vào bảng frame_mappings trong PostgreSQL.
    """
    try:
        cur.execute("""
            INSERT INTO frame_mappings (video_id, frame_path, pts_time, frame_idx, fps, milvus_id)
            VALUES (%s, %s, %s, %s, %s, %s)
            ON CONFLICT (frame_path) DO NOTHING
        """, (video_id, frame_path, pts_time, frame_idx, fps, milvus_id))
        conn.commit()
    except Exception as e:
        print(f"❌ Lỗi insert Postgres cho {frame_path}: {e}")

def index_videos():
    """
    Pipeline lập chỉ mục video: mã hóa frame, lưu vector vào Milvus và metadata vào PostgreSQL.
    """
    # Duyệt các thư mục nhóm (keyframes_L21, keyframes_L22,...)
    for group_dir in os.listdir(FRAME_DIR):
        group_path = os.path.join(FRAME_DIR, group_dir)
        if not os.path.isdir(group_path):
            continue

        # Duyệt thư mục video con (L21_V001, L21_V002,...)
        for key_frame_dir in os.listdir(group_path):
            frame_dir_path = os.path.join(group_path, key_frame_dir)
            if not os.path.isdir(frame_dir_path):
                continue

            # CSV và video path
            csv_path = os.path.join(CSV_DIR, f"{key_frame_dir}.csv")
            video_folder_candidates = [f for f in os.listdir(VIDEO_DIR) if group_dir.replace("keyframes_", "videos_") in f]
            if not os.path.exists(csv_path) or not video_folder_candidates:
                print(f"⚠️ Thiếu CSV hoặc video cho {key_frame_dir}, bỏ qua.")
                continue

            video_path = os.path.join(VIDEO_DIR, video_folder_candidates[0], f"{key_frame_dir}.mp4")
            if not os.path.exists(video_path):
                print(f"⚠️ Không tìm thấy file video {video_path}, bỏ qua.")
                continue

            # Đọc CSV
            mapping_df = pd.read_csv(csv_path)

            # Chèn video vào PostgreSQL hoặc lấy video_id
            cur.execute("""
                INSERT INTO videos (video_path, title, description)
                VALUES (%s, %s, %s)
                ON CONFLICT (video_path) DO NOTHING
                RETURNING id
            """, (video_path.replace("\\", "/"), os.path.basename(video_path), "Video demo"))
            row = cur.fetchone()
            if row:
                video_id = row[0]
            else:
                cur.execute("SELECT id FROM videos WHERE video_path=%s", (video_path.replace("\\", "/"),))
                row = cur.fetchone()
                if row:
                    video_id = row[0]
                else:
                    print(f"❌ Không tìm thấy video {video_path}, bỏ qua.")
                    continue

            # Duyệt từng frame trong thư mục video
            for frame_file in os.listdir(frame_dir_path):
                if not frame_file.endswith((".jpg", ".jpeg", ".png")):
                    continue
                frame_path = os.path.join(frame_dir_path, frame_file).replace("\\", "/")
                try:
                    frame_idx = int(os.path.splitext(frame_file)[0])
                except ValueError:
                    continue

                row = mapping_df[mapping_df["n"] == frame_idx]
                if row.empty:
                    continue
                pts_time = float(row["pts_time"].values[0])
                fps = int(row["fps"].values[0])

                # Encode frame
                emb = encode_image(frame_path)
                if emb is None:
                    continue

                # Insert vào Milvus và PostgreSQL
                milvus_id = insert_to_milvus(frame_path, emb)
                if milvus_id is None:
                    continue
                insert_to_postgres(video_id, frame_path, pts_time, frame_idx, fps, milvus_id)

            conn.commit()
            print(f"✅ Indexed {key_frame_dir}")

# ================== Chạy index ==================
index_videos()
# Out:
# ✅ Indexed L27_V002
# ✅ Indexed L27_V010
# ✅ Indexed L27_V007
# ✅ Indexed L27_V005
# ✅ Indexed L27_V006
# ✅ Indexed L27_V001
# ✅ Indexed L27_V015
# ✅ Indexed L27_V012
# ✅ Indexed L27_V004
# ✅ Indexed L27_V008
# ✅ Indexed L27_V014
# ✅ Indexed L27_V013
# ✅ Indexed L27_V011
# ✅ Indexed L27_V016
# ✅ Indexed L27_V003
# ✅ Indexed L27_V009
# ✅ Indexed L29_V011
# ✅ Indexed L29_V013
# ✅ Indexed L29_V009
# ✅ Indexed L29_V008
# ✅ Indexed L29_V007
# ✅ Indexed L29_V020
# ✅ Indexed L29_V003
# ✅ Indexed L29_V017
# ✅ Indexed L29_V014
# ✅ Indexed L29_V016
# ✅ Indexed L29_V002
# ✅ Indexed L29_V001
# ✅ Indexed L29_V012
# ✅ Indexed L29_V019
# ✅ Indexed L29_V010
# ✅ Indexed L29_V023
# ✅ Indexed L29_V004
# ✅ Indexed L29_V015
# ✅ Indexed L29_V018
# ✅ Indexed L29_V022
# ✅ Indexed L29_V005
# ✅ Indexed L29_V021
# ✅ Indexed L29_V006
# ✅ Indexed L30_V025
# ✅ Indexed L30_V033
# ✅ Indexed L30_V083
# ✅ Indexed L30_V052
# ✅ Indexed L30_V054
# ✅ Indexed L30_V012
# ✅ Indexed L30_V046
# ✅ Indexed L30_V040
# ✅ Indexed L30_V020
# ✅ Indexed L30_V027
# ✅ Indexed L30_V005
# ✅ Indexed L30_V092
# ✅ Indexed L30_V055
# ✅ Indexed L30_V034
# ✅ Indexed L30_V063
# ✅ Indexed L30_V059
# ✅ Indexed L30_V094
# ✅ Indexed L30_V091
# ✅ Indexed L30_V056
# ✅ Indexed L30_V002
# ✅ Indexed L30_V077
# ✅ Indexed L30_V001
# ✅ Indexed L30_V064
# ✅ Indexed L30_V070
# ✅ Indexed L30_V076
# ✅ Indexed L30_V068
# ✅ Indexed L30_V090
# ✅ Indexed L30_V018
# ✅ Indexed L30_V014
# ✅ Indexed L30_V038
# ✅ Indexed L30_V015
# ✅ Indexed L30_V004
# ✅ Indexed L30_V049
# ✅ Indexed L30_V081
# ✅ Indexed L30_V086
# ✅ Indexed L30_V029
# ✅ Indexed L30_V051
# ✅ Indexed L30_V024
# ✅ Indexed L30_V087
# ✅ Indexed L30_V041
# ✅ Indexed L30_V071
# ✅ Indexed L30_V066
# ✅ Indexed L30_V022
# ✅ Indexed L30_V044
# ✅ Indexed L30_V032
# ✅ Indexed L30_V037
# ✅ Indexed L30_V013
# ✅ Indexed L30_V096
# ✅ Indexed L30_V057
# ✅ Indexed L30_V069
# ✅ Indexed L30_V085
# ✅ Indexed L30_V072
# ✅ Indexed L30_V021
# ✅ Indexed L30_V031
# ✅ Indexed L30_V039
# ✅ Indexed L30_V095
# ✅ Indexed L30_V080
# ✅ Indexed L30_V016
# ✅ Indexed L30_V043
# ✅ Indexed L30_V003
# ✅ Indexed L30_V048
# ✅ Indexed L30_V061
# ✅ Indexed L30_V084
# ✅ Indexed L30_V036
# ✅ Indexed L30_V075
# ✅ Indexed L30_V060
# ✅ Indexed L30_V009
# ✅ Indexed L30_V047
# ✅ Indexed L30_V074
# ✅ Indexed L30_V073
# ✅ Indexed L30_V026
# ✅ Indexed L30_V006
# ✅ Indexed L30_V082
# ✅ Indexed L30_V078
# ✅ Indexed L30_V050
# ✅ Indexed L30_V035
# ✅ Indexed L30_V062
# ✅ Indexed L30_V093
# ✅ Indexed L30_V010
# ✅ Indexed L30_V030
# ✅ Indexed L30_V065
# ✅ Indexed L30_V019
# ✅ Indexed L30_V067
# ✅ Indexed L30_V045
# ✅ Indexed L30_V058
# ✅ Indexed L30_V079
# ✅ Indexed L30_V017
# ✅ Indexed L30_V042
# ✅ Indexed L30_V011
# ✅ Indexed L30_V053
# ✅ Indexed L30_V088
# ✅ Indexed L30_V023
# ✅ Indexed L30_V008
# ✅ Indexed L30_V007
# ✅ Indexed L30_V028
# ✅ Indexed L30_V089
# ✅ Indexed L25_V045
# ✅ Indexed L25_V069
# ✅ Indexed L25_V055
# ✅ Indexed L25_V018
# ✅ Indexed L25_V057
# ✅ Indexed L25_V023
# ✅ Indexed L25_V070
# ✅ Indexed L25_V038
# ✅ Indexed L25_V078
# ✅ Indexed L25_V056
# ✅ Indexed L25_V019
# ✅ Indexed L25_V049
# ✅ Indexed L25_V051
# ✅ Indexed L25_V029
# ✅ Indexed L25_V002
# ✅ Indexed L25_V037
# ✅ Indexed L25_V035
# ✅ Indexed L25_V061
# ✅ Indexed L25_V016
# ✅ Indexed L25_V088
# ✅ Indexed L25_V048
# ✅ Indexed L25_V011
# ✅ Indexed L25_V080
# ✅ Indexed L25_V085
# ✅ Indexed L25_V082
# ✅ Indexed L25_V040
# ✅ Indexed L25_V032
# ✅ Indexed L25_V043
# ✅ Indexed L25_V064
# ✅ Indexed L25_V014
# ✅ Indexed L25_V071
# ✅ Indexed L25_V073
# ✅ Indexed L25_V004
# ✅ Indexed L25_V026
# ✅ Indexed L25_V060
# ✅ Indexed L25_V020
# ✅ Indexed L25_V025
# ✅ Indexed L25_V074
# ✅ Indexed L25_V068
# ✅ Indexed L25_V008
# ✅ Indexed L25_V072
# ✅ Indexed L25_V077
# ✅ Indexed L25_V036
# ✅ Indexed L25_V041
# ✅ Indexed L25_V081
# ✅ Indexed L25_V013
# ✅ Indexed L25_V075
# ✅ Indexed L25_V083
# ✅ Indexed L25_V042
# ✅ Indexed L25_V079
# ✅ Indexed L25_V028
# ✅ Indexed L25_V087
# ✅ Indexed L25_V039
# ✅ Indexed L25_V076
# ✅ Indexed L25_V058
# ✅ Indexed L25_V053
# ✅ Indexed L25_V062
# ✅ Indexed L25_V003
# ✅ Indexed L25_V010
# ✅ Indexed L25_V033
# ✅ Indexed L25_V067
# ✅ Indexed L25_V031
# ✅ Indexed L25_V024
# ✅ Indexed L25_V063
# ✅ Indexed L25_V006
# ✅ Indexed L25_V017
# ✅ Indexed L25_V030
# ✅ Indexed L25_V052
# ✅ Indexed L25_V007
# ✅ Indexed L25_V047
# ✅ Indexed L25_V044
# ✅ Indexed L25_V022
# ✅ Indexed L25_V054
# ✅ Indexed L25_V059
# ✅ Indexed L25_V012
# ✅ Indexed L25_V065
# ✅ Indexed L25_V086
# ✅ Indexed L25_V046
# ✅ Indexed L25_V001
# ✅ Indexed L25_V034
# ✅ Indexed L25_V021
# ✅ Indexed L25_V009
# ✅ Indexed L25_V050
# ✅ Indexed L25_V066
# ✅ Indexed L25_V027
# ✅ Indexed L25_V015
# ✅ Indexed L25_V084
# ✅ Indexed L25_V005
# ⚠️ Thiếu CSV hoặc video cho L26_V187, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V142, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V135, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V194, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V146, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V117, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V190, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V157, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V127, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V189, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V168, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V106, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V196, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V111, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V122, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V134, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V155, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V172, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V119, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V121, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V182, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V124, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V156, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V176, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V160, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V165, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V163, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V180, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V179, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V115, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V141, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V116, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V152, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V103, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V102, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V188, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V131, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V158, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V174, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V185, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V169, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V147, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V100, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V164, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V162, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V154, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V177, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V144, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V159, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V195, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V149, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V120, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V126, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V145, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V193, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V108, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V138, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V125, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V181, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V191, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V175, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V178, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V186, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V170, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V166, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V130, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V109, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V101, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V114, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V136, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V167, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V140, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V107, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V150, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V148, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V171, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V129, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V151, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V137, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V104, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V118, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V192, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V161, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V139, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V123, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V143, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V173, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V113, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V128, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V184, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V105, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V197, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V132, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V153, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V110, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V199, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V133, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V112, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V198, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V183, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V223, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V242, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V283, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V260, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V273, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V265, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V250, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V289, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V256, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V233, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V215, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V286, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V238, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V200, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V227, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V230, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V237, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V264, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V211, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V258, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V217, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V271, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V275, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V226, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V272, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V290, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V294, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V214, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V269, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V205, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V299, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V252, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V212, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V277, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V249, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V251, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V298, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V231, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V234, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V220, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V281, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V218, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V261, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V285, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V213, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V202, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V253, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V276, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V222, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V216, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V219, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V279, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V232, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V274, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V280, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V244, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V224, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V241, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V296, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V278, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V239, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V297, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V240, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V206, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V208, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V235, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V209, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V291, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V270, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V292, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V246, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V225, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V221, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V248, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V255, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V254, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V266, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V267, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V203, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V257, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V243, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V207, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V262, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V245, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V282, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V201, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V247, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V210, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V293, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V228, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V236, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V204, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V288, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V263, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V229, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V295, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V268, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V287, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V284, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V259, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V078, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V038, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V010, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V071, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V066, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V048, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V039, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V025, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V060, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V098, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V026, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V031, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V086, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V040, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V080, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V015, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V034, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V042, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V049, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V044, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V021, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V057, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V012, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V019, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V068, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V077, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V037, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V045, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V032, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V011, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V014, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V065, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V027, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V013, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V006, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V099, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V061, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V023, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V020, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V029, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V074, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V090, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V054, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V041, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V070, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V093, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V088, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V017, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V009, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V069, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V050, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V087, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V084, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V064, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V079, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V007, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V001, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V051, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V030, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V003, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V016, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V089, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V052, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V055, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V046, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V075, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V094, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V035, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V058, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V095, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V067, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V076, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V083, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V085, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V053, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V043, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V081, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V062, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V024, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V092, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V018, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V063, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V033, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V028, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V097, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V002, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V022, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V005, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V036, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V073, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V056, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V096, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V059, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V047, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V004, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V082, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V008, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V091, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V072, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V312, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V369, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V327, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V357, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V309, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V361, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V388, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V350, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V304, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V343, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V336, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V386, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V380, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V344, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V371, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V340, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V338, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V355, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V368, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V366, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V375, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V348, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V342, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V331, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V322, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V330, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V392, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V360, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V347, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V334, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V362, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V358, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V354, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V396, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V319, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V308, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V374, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V303, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V325, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V324, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V383, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V314, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V381, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V321, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V317, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V395, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V389, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V341, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V370, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V318, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V313, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V329, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V352, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V333, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V301, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V302, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V390, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V328, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V339, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V320, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V393, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V332, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V394, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V345, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V365, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V373, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V337, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V349, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V326, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V346, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V311, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V376, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V356, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V398, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V306, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V363, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V391, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V397, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V377, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V384, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V387, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V378, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V379, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V300, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V305, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V315, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V307, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V367, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V372, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V364, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V316, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V310, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V323, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V353, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V399, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V335, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V351, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V382, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V385, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V359, bỏ qua.
# ✅ Indexed L23_V009
# ✅ Indexed L23_V005
# ✅ Indexed L23_V011
# ✅ Indexed L23_V020
# ✅ Indexed L23_V015
# ✅ Indexed L23_V024
# ✅ Indexed L23_V016
# ✅ Indexed L23_V022
# ✅ Indexed L23_V004
# ✅ Indexed L23_V019
# ✅ Indexed L23_V013
# ✅ Indexed L23_V025
# ✅ Indexed L23_V003
# ✅ Indexed L23_V014
# ✅ Indexed L23_V001
# ✅ Indexed L23_V002
# ✅ Indexed L23_V008
# ✅ Indexed L23_V021
# ✅ Indexed L23_V012
# ✅ Indexed L23_V007
# ✅ Indexed L23_V023
# ✅ Indexed L23_V010
# ✅ Indexed L23_V006
# ✅ Indexed L23_V017
# ✅ Indexed L23_V018
# ✅ Indexed L22_V007
# ✅ Indexed L22_V017
# ✅ Indexed L22_V030
# ✅ Indexed L22_V004
# ✅ Indexed L22_V006
# ✅ Indexed L22_V025
# ✅ Indexed L22_V024
# ✅ Indexed L22_V003
# ✅ Indexed L22_V022
# ✅ Indexed L22_V014
# ✅ Indexed L22_V019
# ✅ Indexed L22_V015
# ✅ Indexed L22_V009
# ✅ Indexed L22_V016
# ✅ Indexed L22_V023
# ✅ Indexed L22_V026
# ✅ Indexed L22_V011
# ✅ Indexed L22_V028
# ✅ Indexed L22_V013
# ✅ Indexed L22_V027
# ✅ Indexed L22_V002
# ✅ Indexed L22_V029
# ✅ Indexed L22_V018
# ✅ Indexed L22_V020
# ✅ Indexed L22_V021
# ✅ Indexed L22_V008
# ✅ Indexed L22_V005
# ✅ Indexed L22_V001
# ✅ Indexed L22_V010
# ✅ Indexed L22_V031
# ✅ Indexed L22_V012
# ✅ Indexed L28_V001
# ✅ Indexed L28_V008
# ✅ Indexed L28_V014
# ✅ Indexed L28_V009
# ✅ Indexed L28_V020
# ✅ Indexed L28_V024
# ✅ Indexed L28_V005
# ✅ Indexed L28_V022
# ✅ Indexed L28_V011
# ✅ Indexed L28_V010
# ✅ Indexed L28_V002
# ✅ Indexed L28_V007
# ✅ Indexed L28_V017
# ✅ Indexed L28_V023
# ✅ Indexed L28_V012
# ✅ Indexed L28_V021
# ✅ Indexed L28_V013
# ✅ Indexed L28_V019
# ✅ Indexed L28_V006
# ✅ Indexed L28_V004
# ✅ Indexed L28_V015
# ✅ Indexed L28_V018
# ✅ Indexed L28_V016
# ✅ Indexed L28_V003
# ✅ Indexed L21_V009
# ✅ Indexed L21_V014
# ✅ Indexed L21_V019
# ✅ Indexed L21_V002
# ✅ Indexed L21_V013
# ✅ Indexed L21_V021
# ✅ Indexed L21_V001
# ✅ Indexed L21_V016
# ✅ Indexed L21_V018
# ✅ Indexed L21_V007
# ✅ Indexed L21_V023
# ✅ Indexed L21_V017
# ✅ Indexed L21_V026
# ✅ Indexed L21_V031
# ✅ Indexed L21_V003
# ✅ Indexed L21_V005
# ✅ Indexed L21_V015
# ✅ Indexed L21_V028
# ✅ Indexed L21_V022
# ✅ Indexed L21_V029
# ✅ Indexed L21_V024
# ✅ Indexed L21_V010
# ✅ Indexed L21_V025
# ✅ Indexed L21_V006
# ✅ Indexed L21_V008
# ✅ Indexed L21_V012
# ✅ Indexed L21_V030
# ✅ Indexed L21_V011
# ✅ Indexed L21_V027
# ✅ Indexed L24_V043
# ✅ Indexed L24_V042
# ✅ Indexed L24_V035
# ✅ Indexed L24_V003
# ✅ Indexed L24_V020
# ✅ Indexed L24_V040
# ✅ Indexed L24_V017
# ✅ Indexed L24_V018
# ✅ Indexed L24_V022
# ✅ Indexed L24_V019
# ✅ Indexed L24_V041
# ✅ Indexed L24_V010
# ✅ Indexed L24_V039
# ✅ Indexed L24_V006
# ✅ Indexed L24_V009
# ✅ Indexed L24_V027
# ✅ Indexed L24_V007
# ✅ Indexed L24_V028
# ✅ Indexed L24_V002
# ✅ Indexed L24_V021
# ✅ Indexed L24_V038
# ✅ Indexed L24_V029
# ✅ Indexed L24_V015
# ✅ Indexed L24_V044
# ✅ Indexed L24_V011
# ✅ Indexed L24_V013
# ✅ Indexed L24_V026
# ✅ Indexed L24_V004
# ✅ Indexed L24_V023
# ✅ Indexed L24_V005
# ✅ Indexed L24_V033
# ✅ Indexed L24_V016
# ✅ Indexed L24_V030
# ✅ Indexed L24_V031
# ✅ Indexed L24_V008
# ✅ Indexed L24_V012
# ✅ Indexed L24_V025
# ✅ Indexed L24_V024
# ✅ Indexed L24_V036
# ✅ Indexed L24_V014
# ✅ Indexed L24_V037
# ✅ Indexed L24_V045
# ✅ Indexed L24_V032
# ⚠️ Thiếu CSV hoặc video cho L26_V478, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V454, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V467, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V494, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V499, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V462, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V408, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V413, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V439, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V401, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V443, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V455, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V414, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V472, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V456, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V400, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V473, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V457, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V423, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V481, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V441, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V493, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V421, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V434, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V444, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V465, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V419, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V433, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V430, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V415, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V464, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V403, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V409, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V470, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V437, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V488, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V405, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V449, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V432, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V453, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V438, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V427, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V489, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V463, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V461, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V406, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V483, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V497, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V410, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V469, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V452, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V448, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V476, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V447, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V412, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V429, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V459, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V491, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V431, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V424, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V435, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V487, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V484, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V402, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V475, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V445, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V404, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V471, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V425, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V428, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V420, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V440, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V477, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V422, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V418, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V479, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V407, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V411, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V451, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V490, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V496, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V485, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V466, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V495, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V458, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V482, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V474, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V446, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V460, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V436, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V442, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V480, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V492, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V486, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V426, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V468, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V498, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V450, bỏ qua.
# ⚠️ Thiếu CSV hoặc video cho L26_V416, bỏ qua.

# %% [markdown]
# # fix L26

# %%
from pymilvus import Collection

collection_name = "text_image_video_collection"
collection = Collection(collection_name)  # dùng kết nối mặc định 'default'

def index_videos_incremental():
    """
    Chỉ index các video/frame chưa có trong PostgreSQL / Milvus.
    """
    for group_dir in os.listdir(FRAME_DIR):
        group_path = os.path.join(FRAME_DIR, group_dir)
        if not os.path.isdir(group_path):
            continue

        video_folder_candidates = [f for f in os.listdir(VIDEO_DIR) if group_dir.replace("keyframes_", "videos_") in f]
        if not video_folder_candidates:
            print(f"⚠️ Không tìm thấy thư mục video {group_dir.replace('keyframes_', 'videos_')}, bỏ qua group {group_dir}")
            continue
        video_folder = os.path.join(VIDEO_DIR, video_folder_candidates[0])

        for key_frame_dir in os.listdir(group_path):
            frame_dir_path = os.path.join(group_path, key_frame_dir)
            if not os.path.isdir(frame_dir_path):
                continue

            csv_path = os.path.join(CSV_DIR, f"{key_frame_dir}.csv")
            if not os.path.exists(csv_path):
                print(f"⚠️ Thiếu CSV {csv_path}, bỏ qua {key_frame_dir}")
                continue

            # Lấy video_id nếu đã tồn tại trong DB
            cur.execute("SELECT id FROM videos WHERE video_path=%s", (os.path.join(video_folder, f"{key_frame_dir}.mp4").replace("\\","/"),))
            row = cur.fetchone()
            if row:
                video_id = row[0]
            else:
                # Chèn video mới
                cur.execute("""
                    INSERT INTO videos (video_path, title, description)
                    VALUES (%s, %s, %s)
                    RETURNING id
                """, (os.path.join(video_folder, f"{key_frame_dir}.mp4").replace("\\","/"), key_frame_dir, "Video demo"))
                video_id = cur.fetchone()[0]
                conn.commit()

            mapping_df = pd.read_csv(csv_path)

            for frame_file in os.listdir(frame_dir_path):
                if not frame_file.endswith((".jpg", ".jpeg", ".png")):
                    continue
                frame_path = os.path.join(frame_dir_path, frame_file).replace("\\","/")

                # Kiểm tra nếu frame đã có trong DB
                cur.execute("SELECT 1 FROM frame_mappings WHERE frame_path=%s", (frame_path,))
                if cur.fetchone():
                    continue  # đã index, bỏ qua

                try:
                    frame_idx = int(os.path.splitext(frame_file)[0])
                except ValueError:
                    continue

                row = mapping_df[mapping_df["n"] == frame_idx]
                if row.empty:
                    continue
                pts_time = float(row["pts_time"].values[0])
                fps = int(row["fps"].values[0])

                emb = encode_image(frame_path)
                if emb is None:
                    continue

                # Insert vào Milvus
                try:
                    mr = collection.insert([{"vector": emb.tolist(), "frame_path": frame_path}])
                    milvus_id = mr.primary_keys[0]
                except Exception as e:
                    print(f"❌ Lỗi insert Milvus cho {frame_path}: {e}")
                    continue

                # Insert vào PostgreSQL
                insert_to_postgres(video_id, frame_path, pts_time, frame_idx, fps, milvus_id)

            conn.commit()
            print(f"✅ Indexed {key_frame_dir}")

# Chạy index incremental
index_videos_incremental()
# Out:
# Đã xóa 0 bản ghi từ frame_mappings.
# Đã xóa 1 bản ghi từ videos.

# %%
from pymilvus import Collection

collection_name = "text_image_video_collection"
collection = Collection(collection_name)  # dùng kết nối mặc định 'default'

def index_videos_incremental():
    """
    Chỉ index các video/frame chưa có trong PostgreSQL / Milvus.
    """
    for group_dir in os.listdir(FRAME_DIR):
        group_path = os.path.join(FRAME_DIR, group_dir)
        if not os.path.isdir(group_path):
            continue

        video_folder_candidates = [f for f in os.listdir(VIDEO_DIR) if group_dir.replace("keyframes_", "videos_") in f]
        if not video_folder_candidates:
            print(f"⚠️ Không tìm thấy thư mục video {group_dir.replace('keyframes_', 'videos_')}, bỏ qua group {group_dir}")
            continue
        video_folder = os.path.join(VIDEO_DIR, video_folder_candidates[0])

        for key_frame_dir in os.listdir(group_path):
            frame_dir_path = os.path.join(group_path, key_frame_dir)
            if not os.path.isdir(frame_dir_path):
                continue

            csv_path = os.path.join(CSV_DIR, f"{key_frame_dir}.csv")
            if not os.path.exists(csv_path):
                print(f"⚠️ Thiếu CSV {csv_path}, bỏ qua {key_frame_dir}")
                continue

            # Lấy video_id nếu đã tồn tại trong DB
            cur.execute("SELECT id FROM videos WHERE video_path=%s", (os.path.join(video_folder, f"{key_frame_dir}.mp4").replace("\\","/"),))
            row = cur.fetchone()
            if row:
                video_id = row[0]
            else:
                # Chèn video mới
                cur.execute("""
                    INSERT INTO videos (video_path, title, description)
                    VALUES (%s, %s, %s)
                    RETURNING id
                """, (os.path.join(video_folder, f"{key_frame_dir}.mp4").replace("\\","/"), key_frame_dir, "Video demo"))
                video_id = cur.fetchone()[0]
                conn.commit()

            mapping_df = pd.read_csv(csv_path)

            for frame_file in os.listdir(frame_dir_path):
                if not frame_file.endswith((".jpg", ".jpeg", ".png")):
                    continue
                frame_path = os.path.join(frame_dir_path, frame_file).replace("\\","/")

                # Kiểm tra nếu frame đã có trong DB
                cur.execute("SELECT 1 FROM frame_mappings WHERE frame_path=%s", (frame_path,))
                if cur.fetchone():
                    continue  # đã index, bỏ qua

                try:
                    frame_idx = int(os.path.splitext(frame_file)[0])
                except ValueError:
                    continue

                row = mapping_df[mapping_df["n"] == frame_idx]
                if row.empty:
                    continue
                pts_time = float(row["pts_time"].values[0])
                fps = int(row["fps"].values[0])

                emb = encode_image(frame_path)
                if emb is None:
                    continue

                # Insert vào Milvus
                try:
                    mr = collection.insert([{"vector": emb.tolist(), "frame_path": frame_path}])
                    milvus_id = mr.primary_keys[0]
                except Exception as e:
                    print(f"❌ Lỗi insert Milvus cho {frame_path}: {e}")
                    continue

                # Insert vào PostgreSQL
                insert_to_postgres(video_id, frame_path, pts_time, frame_idx, fps, milvus_id)

            conn.commit()
            print(f"✅ Indexed {key_frame_dir}")

# Chạy index incremental
index_videos_incremental()
# Out:
# ✅ Indexed L27_V002
# ✅ Indexed L27_V010
# ✅ Indexed L27_V007
# ✅ Indexed L27_V005
# ✅ Indexed L27_V006
# ✅ Indexed L27_V001
# ✅ Indexed L27_V015
# ✅ Indexed L27_V012
# ✅ Indexed L27_V004
# ✅ Indexed L27_V008
# ✅ Indexed L27_V014
# ✅ Indexed L27_V013
# ✅ Indexed L27_V011
# ✅ Indexed L27_V016
# ✅ Indexed L27_V003
# ✅ Indexed L27_V009
# ✅ Indexed L29_V011
# ✅ Indexed L29_V013
# ✅ Indexed L29_V009
# ✅ Indexed L29_V008
# ✅ Indexed L29_V007
# ✅ Indexed L29_V020
# ✅ Indexed L29_V003
# ✅ Indexed L29_V017
# ✅ Indexed L29_V014
# ✅ Indexed L29_V016
# ✅ Indexed L29_V002
# ✅ Indexed L29_V001
# ✅ Indexed L29_V012
# ✅ Indexed L29_V019
# ✅ Indexed L29_V010
# ✅ Indexed L29_V023
# ✅ Indexed L29_V004
# ✅ Indexed L29_V015
# ✅ Indexed L29_V018
# ✅ Indexed L29_V022
# ✅ Indexed L29_V005
# ✅ Indexed L29_V021
# ✅ Indexed L29_V006
# ✅ Indexed L30_V025
# ✅ Indexed L30_V033
# ✅ Indexed L30_V083
# ✅ Indexed L30_V052
# ✅ Indexed L30_V054
# ✅ Indexed L30_V012
# ✅ Indexed L30_V046
# ✅ Indexed L30_V040
# ✅ Indexed L30_V020
# ✅ Indexed L30_V027
# ✅ Indexed L30_V005
# ✅ Indexed L30_V092
# ✅ Indexed L30_V055
# ✅ Indexed L30_V034
# ✅ Indexed L30_V063
# ✅ Indexed L30_V059
# ✅ Indexed L30_V094
# ✅ Indexed L30_V091
# ✅ Indexed L30_V056
# ✅ Indexed L30_V002
# ✅ Indexed L30_V077
# ✅ Indexed L30_V001
# ✅ Indexed L30_V064
# ✅ Indexed L30_V070
# ✅ Indexed L30_V076
# ✅ Indexed L30_V068
# ✅ Indexed L30_V090
# ✅ Indexed L30_V018
# ✅ Indexed L30_V014
# ✅ Indexed L30_V038
# ✅ Indexed L30_V015
# ✅ Indexed L30_V004
# ✅ Indexed L30_V049
# ✅ Indexed L30_V081
# ✅ Indexed L30_V086
# ✅ Indexed L30_V029
# ✅ Indexed L30_V051
# ✅ Indexed L30_V024
# ✅ Indexed L30_V087
# ✅ Indexed L30_V041
# ✅ Indexed L30_V071
# ✅ Indexed L30_V066
# ✅ Indexed L30_V022
# ✅ Indexed L30_V044
# ✅ Indexed L30_V032
# ✅ Indexed L30_V037
# ✅ Indexed L30_V013
# ✅ Indexed L30_V096
# ✅ Indexed L30_V057
# ✅ Indexed L30_V069
# ✅ Indexed L30_V085
# ✅ Indexed L30_V072
# ✅ Indexed L30_V021
# ✅ Indexed L30_V031
# ✅ Indexed L30_V039
# ✅ Indexed L30_V095
# ✅ Indexed L30_V080
# ✅ Indexed L30_V016
# ✅ Indexed L30_V043
# ✅ Indexed L30_V003
# ✅ Indexed L30_V048
# ✅ Indexed L30_V061
# ✅ Indexed L30_V084
# ✅ Indexed L30_V036
# ✅ Indexed L30_V075
# ✅ Indexed L30_V060
# ✅ Indexed L30_V009
# ✅ Indexed L30_V047
# ✅ Indexed L30_V074
# ✅ Indexed L30_V073
# ✅ Indexed L30_V026
# ✅ Indexed L30_V006
# ✅ Indexed L30_V082
# ✅ Indexed L30_V078
# ✅ Indexed L30_V050
# ✅ Indexed L30_V035
# ✅ Indexed L30_V062
# ✅ Indexed L30_V093
# ✅ Indexed L30_V010
# ✅ Indexed L30_V030
# ✅ Indexed L30_V065
# ✅ Indexed L30_V019
# ✅ Indexed L30_V067
# ✅ Indexed L30_V045
# ✅ Indexed L30_V058
# ✅ Indexed L30_V079
# ✅ Indexed L30_V017
# ✅ Indexed L30_V042
# ✅ Indexed L30_V011
# ✅ Indexed L30_V053
# ✅ Indexed L30_V088
# ✅ Indexed L30_V023
# ✅ Indexed L30_V008
# ✅ Indexed L30_V007
# ✅ Indexed L30_V028
# ✅ Indexed L30_V089
# ✅ Indexed L25_V045
# ✅ Indexed L25_V069
# ✅ Indexed L25_V055
# ✅ Indexed L25_V018
# ✅ Indexed L25_V057
# ✅ Indexed L25_V023
# ✅ Indexed L25_V070
# ✅ Indexed L25_V038
# ✅ Indexed L25_V078
# ✅ Indexed L25_V056
# ✅ Indexed L25_V019
# ✅ Indexed L25_V049
# ✅ Indexed L25_V051
# ✅ Indexed L25_V029
# ✅ Indexed L25_V002
# ✅ Indexed L25_V037
# ✅ Indexed L25_V035
# ✅ Indexed L25_V061
# ✅ Indexed L25_V016
# ✅ Indexed L25_V088
# ✅ Indexed L25_V048
# ✅ Indexed L25_V011
# ✅ Indexed L25_V080
# ✅ Indexed L25_V085
# ✅ Indexed L25_V082
# ✅ Indexed L25_V040
# ✅ Indexed L25_V032
# ✅ Indexed L25_V043
# ✅ Indexed L25_V064
# ✅ Indexed L25_V014
# ✅ Indexed L25_V071
# ✅ Indexed L25_V073
# ✅ Indexed L25_V004
# ✅ Indexed L25_V026
# ✅ Indexed L25_V060
# ✅ Indexed L25_V020
# ✅ Indexed L25_V025
# ✅ Indexed L25_V074
# ✅ Indexed L25_V068
# ✅ Indexed L25_V008
# ✅ Indexed L25_V072
# ✅ Indexed L25_V077
# ✅ Indexed L25_V036
# ✅ Indexed L25_V041
# ✅ Indexed L25_V081
# ✅ Indexed L25_V013
# ✅ Indexed L25_V075
# ✅ Indexed L25_V083
# ✅ Indexed L25_V042
# ✅ Indexed L25_V079
# ✅ Indexed L25_V028
# ✅ Indexed L25_V087
# ✅ Indexed L25_V039
# ✅ Indexed L25_V076
# ✅ Indexed L25_V058
# ✅ Indexed L25_V053
# ✅ Indexed L25_V062
# ✅ Indexed L25_V003
# ✅ Indexed L25_V010
# ✅ Indexed L25_V033
# ✅ Indexed L25_V067
# ✅ Indexed L25_V031
# ✅ Indexed L25_V024
# ✅ Indexed L25_V063
# ✅ Indexed L25_V006
# ✅ Indexed L25_V017
# ✅ Indexed L25_V030
# ✅ Indexed L25_V052
# ✅ Indexed L25_V007
# ✅ Indexed L25_V047
# ✅ Indexed L25_V044
# ✅ Indexed L25_V022
# ✅ Indexed L25_V054
# ✅ Indexed L25_V059
# ✅ Indexed L25_V012
# ✅ Indexed L25_V065
# ✅ Indexed L25_V086
# ✅ Indexed L25_V046
# ✅ Indexed L25_V001
# ✅ Indexed L25_V034
# ✅ Indexed L25_V021
# ✅ Indexed L25_V009
# ✅ Indexed L25_V050
# ✅ Indexed L25_V066
# ✅ Indexed L25_V027
# ✅ Indexed L25_V015
# ✅ Indexed L25_V084
# ✅ Indexed L25_V005
# ✅ Indexed L26_V187
# ✅ Indexed L26_V223
# ✅ Indexed L26_V078
# ✅ Indexed L26_V038
# ✅ Indexed L26_V478
# ✅ Indexed L26_V454
# ✅ Indexed L26_V010
# ✅ Indexed L26_V242
# ✅ Indexed L26_V142
# ✅ Indexed L26_V071
# ✅ Indexed L26_V467
# ✅ Indexed L26_V066
# ✅ Indexed L26_V283
# ✅ Indexed L26_V260
# ✅ Indexed L26_V312
# ✅ Indexed L26_V369
# ✅ Indexed L26_V273
# ✅ Indexed L26_V135
# ✅ Indexed L26_V048
# ✅ Indexed L26_V039
# ✅ Indexed L26_V025
# ✅ Indexed L26_V194
# ✅ Indexed L26_V494
# ✅ Indexed L26_V327
# ✅ Indexed L26_V499
# ✅ Indexed L26_V146
# ✅ Indexed L26_V060
# ✅ Indexed L26_V357
# ✅ Indexed L26_V309
# ✅ Indexed L26_V361
# ✅ Indexed L26_V117
# ✅ Indexed L26_V388
# ✅ Indexed L26_V350
# ✅ Indexed L26_V462
# ✅ Indexed L26_V098
# ✅ Indexed L26_V026
# ✅ Indexed L26_V265
# ✅ Indexed L26_V031
# ✅ Indexed L26_V304
# ✅ Indexed L26_V343
# ✅ Indexed L26_V250
# ✅ Indexed L26_V190
# ✅ Indexed L26_V289
# ✅ Indexed L26_V256
# ✅ Indexed L26_V086
# ✅ Indexed L26_V040
# ✅ Indexed L26_V157
# ✅ Indexed L26_V233
# ✅ Indexed L26_V080
# ✅ Indexed L26_V408
# ✅ Indexed L26_V336
# ✅ Indexed L26_V386
# ✅ Indexed L26_V380
# ✅ Indexed L26_V015
# ✅ Indexed L26_V344
# ✅ Indexed L26_V371
# ✅ Indexed L26_V127
# ✅ Indexed L26_V340
# ✅ Indexed L26_V034
# ✅ Indexed L26_V413
# ✅ Indexed L26_V439
# ✅ Indexed L26_V401
# ✅ Indexed L26_V189
# ✅ Indexed L26_V338
# ✅ Indexed L26_V443
# ✅ Indexed L26_V042
# ✅ Indexed L26_V215
# ✅ Indexed L26_V355
# ✅ Indexed L26_V168
# ✅ Indexed L26_V368
# ✅ Indexed L26_V049
# ✅ Indexed L26_V286
# ✅ Indexed L26_V366
# ✅ Indexed L26_V106
# ✅ Indexed L26_V375
# ✅ Indexed L26_V044
# ✅ Indexed L26_V021
# ✅ Indexed L26_V238
# ✅ Indexed L26_V455
# ✅ Indexed L26_V348
# ✅ Indexed L26_V414
# ✅ Indexed L26_V196
# ✅ Indexed L26_V057
# ✅ Indexed L26_V200
# ✅ Indexed L26_V227
# ✅ Indexed L26_V472
# ✅ Indexed L26_V456
# ✅ Indexed L26_V012
# ✅ Indexed L26_V230
# ✅ Indexed L26_V019
# ✅ Indexed L26_V111
# ✅ Indexed L26_V342
# ✅ Indexed L26_V122
# ✅ Indexed L26_V331
# ✅ Indexed L26_V068
# ✅ Indexed L26_V237
# ✅ Indexed L26_V322
# ✅ Indexed L26_V400
# ✅ Indexed L26_V473
# ✅ Indexed L26_V077
# ✅ Indexed L26_V457
# ✅ Indexed L26_V330
# ✅ Indexed L26_V134
# ✅ Indexed L26_V392
# ✅ Indexed L26_V037
# ✅ Indexed L26_V045
# ✅ Indexed L26_V423
# ✅ Indexed L26_V360
# ✅ Indexed L26_V155
# ✅ Indexed L26_V172
# ✅ Indexed L26_V481
# ✅ Indexed L26_V032
# ✅ Indexed L26_V264
# ✅ Indexed L26_V441
# ✅ Indexed L26_V493
# ✅ Indexed L26_V011
# ✅ Indexed L26_V347
# ✅ Indexed L26_V334
# ✅ Indexed L26_V362
# ✅ Indexed L26_V014
# ✅ Indexed L26_V211
# ✅ Indexed L26_V258
# ✅ Indexed L26_V065
# ✅ Indexed L26_V358
# ✅ Indexed L26_V027
# ✅ Indexed L26_V354
# ✅ Indexed L26_V217
# ✅ Indexed L26_V271
# ✅ Indexed L26_V013
# ✅ Indexed L26_V119
# ✅ Indexed L26_V006
# ✅ Indexed L26_V396
# ✅ Indexed L26_V319
# ✅ Indexed L26_V308
# ✅ Indexed L26_V421
# ✅ Indexed L26_V434
# ✅ Indexed L26_V099
# ✅ Indexed L26_V275
# ✅ Indexed L26_V444
# ✅ Indexed L26_V121
# ✅ Indexed L26_V226
# ✅ Indexed L26_V272
# ✅ Indexed L26_V465
# ✅ Indexed L26_V182
# ✅ Indexed L26_V124
# ✅ Indexed L26_V061
# ✅ Indexed L26_V023
# ✅ Indexed L26_V020
# ✅ Indexed L26_V374
# ✅ Indexed L26_V156
# ✅ Indexed L26_V419
# ✅ Indexed L26_V433
# ✅ Indexed L26_V430
# ✅ Indexed L26_V176
# ✅ Indexed L26_V290
# ✅ Indexed L26_V415
# ✅ Indexed L26_V464
# ✅ Indexed L26_V029
# ✅ Indexed L26_V294
# ✅ Indexed L26_V160
# ✅ Indexed L26_V303
# ✅ Indexed L26_V074
# ✅ Indexed L26_V090
# ✅ Indexed L26_V054
# ✅ Indexed L26_V165
# ✅ Indexed L26_V403
# ✅ Indexed L26_V163
# ✅ Indexed L26_V180
# ✅ Indexed L26_V214
# ✅ Indexed L26_V325
# ✅ Indexed L26_V269
# ✅ Indexed L26_V179
# ✅ Indexed L26_V409
# ✅ Indexed L26_V205
# ✅ Indexed L26_V115
# ✅ Indexed L26_V470
# ✅ Indexed L26_V324
# ✅ Indexed L26_V383
# ✅ Indexed L26_V141
# ✅ Indexed L26_V116
# ✅ Indexed L26_V299
# ✅ Indexed L26_V437
# ✅ Indexed L26_V314
# ✅ Indexed L26_V381
# ✅ Indexed L26_V321
# ✅ Indexed L26_V317
# ✅ Indexed L26_V252
# ✅ Indexed L26_V212
# ✅ Indexed L26_V488
# ✅ Indexed L26_V041
# ✅ Indexed L26_V070
# ✅ Indexed L26_V277
# ✅ Indexed L26_V405
# ✅ Indexed L26_V395
# ✅ Indexed L26_V152
# ✅ Indexed L26_V103
# ✅ Indexed L26_V093
# ✅ Indexed L26_V102
# ✅ Indexed L26_V449
# ✅ Indexed L26_V188
# ✅ Indexed L26_V389
# ✅ Indexed L26_V249
# ✅ Indexed L26_V432
# ✅ Indexed L26_V131
# ✅ Indexed L26_V251
# ✅ Indexed L26_V158
# ✅ Indexed L26_V341
# ✅ Indexed L26_V453
# ✅ Indexed L26_V370
# ✅ Indexed L26_V088
# ✅ Indexed L26_V017
# ✅ Indexed L26_V438
# ✅ Indexed L26_V427
# ✅ Indexed L26_V318
# ✅ Indexed L26_V489
# ✅ Indexed L26_V298
# ✅ Indexed L26_V313
# ✅ Indexed L26_V329
# ✅ Indexed L26_V352
# ✅ Indexed L26_V231
# ✅ Indexed L26_V174
# ✅ Indexed L26_V463
# ✅ Indexed L26_V009
# ✅ Indexed L26_V333
# ✅ Indexed L26_V461
# ✅ Indexed L26_V069
# ✅ Indexed L26_V050
# ✅ Indexed L26_V234
# ✅ Indexed L26_V220
# ✅ Indexed L26_V301
# ✅ Indexed L26_V281
# ✅ Indexed L26_V218
# ✅ Indexed L26_V185
# ✅ Indexed L26_V261
# ✅ Indexed L26_V087
# ✅ Indexed L26_V084
# ✅ Indexed L26_V302
# ✅ Indexed L26_V064
# ✅ Indexed L26_V169
# ✅ Indexed L26_V406
# ✅ Indexed L26_V285
# ✅ Indexed L26_V483
# ✅ Indexed L26_V147
# ✅ Indexed L26_V100
# ✅ Indexed L26_V079
# ✅ Indexed L26_V390
# ✅ Indexed L26_V164
# ✅ Indexed L26_V497
# ✅ Indexed L26_V213
# ✅ Indexed L26_V162
# ✅ Indexed L26_V328
# ✅ Indexed L26_V007
# ✅ Indexed L26_V410
# ✅ Indexed L26_V154
# ✅ Indexed L26_V469
# ✅ Indexed L26_V177
# ✅ Indexed L26_V144
# ✅ Indexed L26_V339
# ✅ Indexed L26_V452
# ✅ Indexed L26_V159
# ✅ Indexed L26_V195
# ✅ Indexed L26_V320
# ✅ Indexed L26_V393
# ✅ Indexed L26_V448
# ✅ Indexed L26_V149
# ✅ Indexed L26_V001
# ✅ Indexed L26_V051
# ✅ Indexed L26_V030
# ✅ Indexed L26_V202
# ✅ Indexed L26_V253
# ✅ Indexed L26_V276
# ✅ Indexed L26_V003
# ✅ Indexed L26_V222
# ✅ Indexed L26_V476
# ✅ Indexed L26_V120
# ✅ Indexed L26_V216
# ✅ Indexed L26_V447
# ✅ Indexed L26_V412
# ✅ Indexed L26_V016
# ✅ Indexed L26_V429
# ✅ Indexed L26_V459
# ✅ Indexed L26_V089
# ✅ Indexed L26_V126
# ✅ Indexed L26_V145
# ✅ Indexed L26_V219
# ✅ Indexed L26_V279
# ✅ Indexed L26_V491
# ✅ Indexed L26_V232
# ✅ Indexed L26_V274
# ✅ Indexed L26_V280
# ✅ Indexed L26_V052
# ✅ Indexed L26_V431
# ✅ Indexed L26_V244
# ✅ Indexed L26_V193
# ✅ Indexed L26_V332
# ✅ Indexed L26_V424
# ✅ Indexed L26_V435
# ✅ Indexed L26_V224
# ✅ Indexed L26_V241
# ✅ Indexed L26_V487
# ✅ Indexed L26_V296
# ✅ Indexed L26_V108
# ✅ Indexed L26_V055
# ✅ Indexed L26_V278
# ✅ Indexed L26_V394
# ✅ Indexed L26_V345
# ✅ Indexed L26_V239
# ✅ Indexed L26_V297
# ✅ Indexed L26_V240
# ✅ Indexed L26_V206
# ✅ Indexed L26_V208
# ✅ Indexed L26_V235
# ✅ Indexed L26_V484
# ✅ Indexed L26_V402
# ✅ Indexed L26_V046
# ✅ Indexed L26_V475
# ✅ Indexed L26_V209
# ✅ Indexed L26_V445
# ✅ Indexed L26_V138
# ✅ Indexed L26_V075
# ✅ Indexed L26_V125
# ✅ Indexed L26_V181
# ✅ Indexed L26_V365
# ✅ Indexed L26_V373
# ✅ Indexed L26_V404
# ✅ Indexed L26_V191
# ✅ Indexed L26_V291
# ✅ Indexed L26_V094
# ✅ Indexed L26_V471
# ✅ Indexed L26_V270
# ✅ Indexed L26_V035
# ✅ Indexed L26_V425
# ✅ Indexed L26_V337
# ✅ Indexed L26_V058
# ✅ Indexed L26_V175
# ✅ Indexed L26_V292
# ✅ Indexed L26_V178
# ✅ Indexed L26_V428
# ✅ Indexed L26_V246
# ✅ Indexed L26_V095
# ✅ Indexed L26_V349
# ✅ Indexed L26_V326
# ✅ Indexed L26_V067
# ✅ Indexed L26_V420
# ✅ Indexed L26_V076
# ✅ Indexed L26_V440
# ✅ Indexed L26_V186
# ✅ Indexed L26_V083
# ✅ Indexed L26_V477
# ✅ Indexed L26_V225
# ✅ Indexed L26_V422
# ✅ Indexed L26_V221
# ✅ Indexed L26_V418
# ✅ Indexed L26_V248
# ✅ Indexed L26_V170
# ✅ Indexed L26_V346
# ✅ Indexed L26_V255
# ✅ Indexed L26_V166
# ✅ Indexed L26_V130
# ✅ Indexed L26_V254
# ✅ Indexed L26_V479
# ✅ Indexed L26_V407
# ✅ Indexed L26_V311
# ✅ Indexed L26_V266
# ✅ Indexed L26_V109
# ✅ Indexed L26_V267
# ✅ Indexed L26_V203
# ✅ Indexed L26_V101
# ✅ Indexed L26_V114
# ✅ Indexed L26_V257
# ✅ Indexed L26_V411
# ✅ Indexed L26_V376
# ✅ Indexed L26_V136
# ✅ Indexed L26_V085
# ✅ Indexed L26_V053
# ✅ Indexed L26_V356
# ✅ Indexed L26_V167
# ✅ Indexed L26_V451
# ✅ Indexed L26_V140
# ✅ Indexed L26_V243
# ✅ Indexed L26_V107
# ✅ Indexed L26_V150
# ✅ Indexed L26_V490
# ✅ Indexed L26_V148
# ✅ Indexed L26_V171
# ✅ Indexed L26_V496
# ✅ Indexed L26_V129
# ✅ Indexed L26_V485
# ✅ Indexed L26_V043
# ✅ Indexed L26_V466
# ✅ Indexed L26_V398
# ✅ Indexed L26_V495
# ✅ Indexed L26_V207
# ✅ Indexed L26_V458
# ✅ Indexed L26_V482
# ✅ Indexed L26_V262
# ✅ Indexed L26_V245
# ✅ Indexed L26_V081
# ✅ Indexed L26_V151
# ✅ Indexed L26_V474
# ✅ Indexed L26_V306
# ✅ Indexed L26_V363
# ✅ Indexed L26_V282
# ✅ Indexed L26_V391
# ✅ Indexed L26_V397
# ✅ Indexed L26_V201
# ✅ Indexed L26_V377
# ✅ Indexed L26_V137
# ✅ Indexed L26_V247
# ✅ Indexed L26_V210
# ✅ Indexed L26_V293
# ✅ Indexed L26_V446
# ✅ Indexed L26_V104
# ✅ Indexed L26_V062
# ✅ Indexed L26_V384
# ✅ Indexed L26_V387
# ✅ Indexed L26_V378
# ✅ Indexed L26_V379
# ✅ Indexed L26_V460
# ✅ Indexed L26_V228
# ✅ Indexed L26_V300
# ✅ Indexed L26_V436
# ✅ Indexed L26_V305
# ✅ Indexed L26_V024
# ✅ Indexed L26_V315
# ✅ Indexed L26_V307
# ✅ Indexed L26_V442
# ✅ Indexed L26_V092
# ✅ Indexed L26_V236
# ✅ Indexed L26_V118
# ✅ Indexed L26_V018
# ✅ Indexed L26_V204
# ✅ Indexed L26_V367
# ✅ Indexed L26_V372
# ✅ Indexed L26_V364
# ✅ Indexed L26_V316
# ✅ Indexed L26_V310
# ✅ Indexed L26_V063
# ✅ Indexed L26_V480
# ✅ Indexed L26_V492
# ✅ Indexed L26_V033
# ✅ Indexed L26_V486
# ✅ Indexed L26_V192
# ✅ Indexed L26_V161
# ✅ Indexed L26_V139
# ✅ Indexed L26_V426
# ✅ Indexed L26_V288
# ✅ Indexed L26_V123
# ✅ Indexed L26_V323
# ✅ Indexed L26_V353
# ✅ Indexed L26_V263
# ✅ Indexed L26_V143
# ✅ Indexed L26_V173
# ✅ Indexed L26_V113
# ✅ Indexed L26_V128
# ✅ Indexed L26_V184
# ✅ Indexed L26_V028
# ✅ Indexed L26_V399
# ✅ Indexed L26_V105
# ✅ Indexed L26_V197
# ✅ Indexed L26_V097
# ✅ Indexed L26_V002
# ✅ Indexed L26_V468
# ✅ Indexed L26_V022
# ✅ Indexed L26_V229
# ✅ Indexed L26_V005
# ✅ Indexed L26_V036
# ✅ Indexed L26_V073
# ✅ Indexed L26_V295
# ✅ Indexed L26_V268
# ✅ Indexed L26_V056
# ✅ Indexed L26_V096
# ✅ Indexed L26_V335
# ✅ Indexed L26_V059
# ✅ Indexed L26_V287
# ✅ Indexed L26_V132
# ✅ Indexed L26_V498
# ✅ Indexed L26_V047
# ✅ Indexed L26_V004
# ✅ Indexed L26_V351
# ✅ Indexed L26_V153
# ✅ Indexed L26_V110
# ✅ Indexed L26_V199
# ✅ Indexed L26_V382
# ✅ Indexed L26_V133
# ✅ Indexed L26_V284
# ✅ Indexed L26_V385
# ✅ Indexed L26_V082
# ✅ Indexed L26_V008
# ✅ Indexed L26_V112
# ✅ Indexed L26_V359
# ✅ Indexed L26_V091
# ✅ Indexed L26_V450
# ✅ Indexed L26_V198
# ✅ Indexed L26_V183
# ✅ Indexed L26_V259
# ✅ Indexed L26_V072
# ✅ Indexed L26_V416
# ⚠️ Không tìm thấy thư mục video videos_L26b, bỏ qua group keyframes_L26b
# ⚠️ Không tìm thấy thư mục video videos_L26c, bỏ qua group keyframes_L26c
# ⚠️ Không tìm thấy thư mục video videos_L26d, bỏ qua group keyframes_L26d
# ✅ Indexed L23_V009
# ✅ Indexed L23_V005
# ✅ Indexed L23_V011
# ✅ Indexed L23_V020
# ✅ Indexed L23_V015
# ✅ Indexed L23_V024
# ✅ Indexed L23_V016
# ✅ Indexed L23_V022
# ✅ Indexed L23_V004
# ✅ Indexed L23_V019
# ✅ Indexed L23_V013
# ✅ Indexed L23_V025
# ✅ Indexed L23_V003
# ✅ Indexed L23_V014
# ✅ Indexed L23_V001
# ✅ Indexed L23_V002
# ✅ Indexed L23_V008
# ✅ Indexed L23_V021
# ✅ Indexed L23_V012
# ✅ Indexed L23_V007
# ✅ Indexed L23_V023
# ✅ Indexed L23_V010
# ✅ Indexed L23_V006
# ✅ Indexed L23_V017
# ✅ Indexed L23_V018
# ✅ Indexed L22_V007
# ✅ Indexed L22_V017
# ✅ Indexed L22_V030
# ✅ Indexed L22_V004
# ✅ Indexed L22_V006
# ✅ Indexed L22_V025
# ✅ Indexed L22_V024
# ✅ Indexed L22_V003
# ✅ Indexed L22_V022
# ✅ Indexed L22_V014
# ✅ Indexed L22_V019
# ✅ Indexed L22_V015
# ✅ Indexed L22_V009
# ✅ Indexed L22_V016
# ✅ Indexed L22_V023
# ✅ Indexed L22_V026
# ✅ Indexed L22_V011
# ✅ Indexed L22_V028
# ✅ Indexed L22_V013
# ✅ Indexed L22_V027
# ✅ Indexed L22_V002
# ✅ Indexed L22_V029
# ✅ Indexed L22_V018
# ✅ Indexed L22_V020
# ✅ Indexed L22_V021
# ✅ Indexed L22_V008
# ✅ Indexed L22_V005
# ✅ Indexed L22_V001
# ✅ Indexed L22_V010
# ✅ Indexed L22_V031
# ✅ Indexed L22_V012
# ✅ Indexed L28_V001
# ✅ Indexed L28_V008
# ✅ Indexed L28_V014
# ✅ Indexed L28_V009
# ✅ Indexed L28_V020
# ✅ Indexed L28_V024
# ✅ Indexed L28_V005
# ✅ Indexed L28_V022
# ✅ Indexed L28_V011
# ✅ Indexed L28_V010
# ✅ Indexed L28_V002
# ✅ Indexed L28_V007
# ✅ Indexed L28_V017
# ✅ Indexed L28_V023
# ✅ Indexed L28_V012
# ✅ Indexed L28_V021
# ✅ Indexed L28_V013
# ✅ Indexed L28_V019
# ✅ Indexed L28_V006
# ✅ Indexed L28_V004
# ✅ Indexed L28_V015
# ✅ Indexed L28_V018
# ✅ Indexed L28_V016
# ✅ Indexed L28_V003
# ✅ Indexed L21_V009
# ✅ Indexed L21_V014
# ✅ Indexed L21_V019
# ✅ Indexed L21_V002
# ✅ Indexed L21_V013
# ✅ Indexed L21_V021
# ✅ Indexed L21_V001
# ✅ Indexed L21_V016
# ✅ Indexed L21_V018
# ✅ Indexed L21_V007
# ✅ Indexed L21_V023
# ✅ Indexed L21_V017
# ✅ Indexed L21_V026
# ✅ Indexed L21_V031
# ✅ Indexed L21_V003
# ✅ Indexed L21_V005
# ✅ Indexed L21_V015
# ✅ Indexed L21_V028
# ✅ Indexed L21_V022
# ✅ Indexed L21_V029
# ✅ Indexed L21_V024
# ✅ Indexed L21_V010
# ✅ Indexed L21_V025
# ✅ Indexed L21_V006
# ✅ Indexed L21_V008
# ✅ Indexed L21_V012
# ✅ Indexed L21_V030
# ✅ Indexed L21_V011
# ✅ Indexed L21_V027
# ✅ Indexed L24_V043
# ✅ Indexed L24_V042
# ✅ Indexed L24_V035
# ✅ Indexed L24_V003
# ✅ Indexed L24_V020
# ✅ Indexed L24_V040
# ✅ Indexed L24_V017
# ✅ Indexed L24_V018
# ✅ Indexed L24_V022
# ✅ Indexed L24_V019
# ✅ Indexed L24_V041
# ✅ Indexed L24_V010
# ✅ Indexed L24_V039
# ✅ Indexed L24_V006
# ✅ Indexed L24_V009
# ✅ Indexed L24_V027
# ✅ Indexed L24_V007
# ✅ Indexed L24_V028
# ✅ Indexed L24_V002
# ✅ Indexed L24_V021
# ✅ Indexed L24_V038
# ✅ Indexed L24_V029
# ✅ Indexed L24_V015
# ✅ Indexed L24_V044
# ✅ Indexed L24_V011
# ✅ Indexed L24_V013
# ✅ Indexed L24_V026
# ✅ Indexed L24_V004
# ✅ Indexed L24_V023
# ✅ Indexed L24_V005
# ✅ Indexed L24_V033
# ✅ Indexed L24_V016
# ✅ Indexed L24_V030
# ✅ Indexed L24_V031
# ✅ Indexed L24_V008
# ✅ Indexed L24_V012
# ✅ Indexed L24_V025
# ✅ Indexed L24_V024
# ✅ Indexed L24_V036
# ✅ Indexed L24_V014
# ✅ Indexed L24_V037
# ✅ Indexed L24_V045
# ✅ Indexed L24_V032
# ⚠️ Không tìm thấy thư mục video videos_L26e, bỏ qua group keyframes_L26e

# %% [markdown]
# # cell 7. nho chay cell 3 truoc

# %%
import pandas as pd
import os
import torch
import torch.nn.functional as F
from pymilvus import Collection

# ================== Các hàm hỗ trợ ==================
def time_to_seconds(time_str):
    try:
        minutes, seconds = map(int, time_str.split(':'))
        return minutes * 60 + seconds
    except ValueError:
        print(f"❌ Lỗi định dạng thời gian: {time_str}")
        return None

def get_frame_idx_from_time(video_path, time_start, time_end, csv_dir):
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    csv_path = os.path.join(csv_dir, f"{video_name}.csv")
    if not os.path.exists(csv_path):
        print(f"❌ Không tìm thấy file CSV: {csv_path}")
        return None
    try:
        df = pd.read_csv(csv_path)
        if not all(col in df.columns for col in ['pts_time', 'frame_idx', 'fps']):
            print(f"❌ CSV {csv_path} thiếu cột cần thiết")
            return None
    except Exception as e:
        print(f"❌ Lỗi đọc CSV {csv_path}: {e}")
        return None

    start_sec = time_to_seconds(time_start)
    end_sec = time_to_seconds(time_end)
    if start_sec is None or end_sec is None:
        return None

    target_time = (start_sec + end_sec) / 2
    df['time_diff'] = abs(df['pts_time'] - target_time)
    closest_row = df.loc[df['time_diff'].idxmin()]
    return int(closest_row['frame_idx'])

def format_time(seconds):
    m = int(seconds // 60)
    s = int(seconds % 60)
    return f"{m}:{s:02d}"

def encode_text(text):
    try:
        inputs = clip_processor(
            text=[text],
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=77
        ).to(device)
        with torch.no_grad():
            text_features = clip_model.get_text_features(**inputs)
        return F.normalize(text_features, p=2, dim=1)[0].cpu().numpy()
    except Exception as e:
        print(f"❌ Lỗi encode text: {e}")
        return None

# ================== Hàm chuẩn LSC/VBS ==================
def group_timestamps(frame_list, gap_threshold=15.0, margin=5.0, min_range=5.0):
    if not frame_list:
        return []

    frame_list = sorted(frame_list, key=lambda x: x[1])
    groups = []
    current_group = [frame_list[0]]

    for i in range(1, len(frame_list)):
        prev_frame, prev_time = frame_list[i - 1]
        cur_frame, cur_time = frame_list[i]

        if cur_time - prev_time <= gap_threshold:
            current_group.append((cur_frame, cur_time))
        else:
            groups.append(current_group)
            current_group = [(cur_frame, cur_time)]
    groups.append(current_group)

    result = []
    for group in groups:
        start_time = max(0, group[0][1] - margin)
        end_time = group[-1][1] + margin
        if end_time - start_time < min_range:
            end_time = start_time + min_range
        frame_idxs = [f[0] for f in group]
        result.append((start_time, end_time, frame_idxs))

    return result


# Cell trước phải chạy
def format_search_results(search_results, csv_dir):
    grouped_results = {}
    for res in search_results:
        video_path = res['video_path']
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        if video_path not in grouped_results:
            grouped_results[video_path] = (video_name, [])
        
        for time_start, time_end in res['time_ranges']:
            frame_idx = get_frame_idx_from_time(video_path, time_start, time_end, csv_dir)
            if frame_idx is not None:
                grouped_results[video_path][1].append((frame_idx, time_start, time_end))
    
    return grouped_results



def search_videos_by_text(text_query, top_k=10, gap_threshold=15.0, margin=5.0, min_range=5.0):
    text_emb = encode_text(text_query)
    if text_emb is None:
        return []

    collection_name = "text_image_video_collection"
    collection = Collection(collection_name)

    results = collection.search(
        data=[text_emb.tolist()],
        anns_field="vector",
        param={"metric_type": "COSINE", "params": {"nprobe": 10}},
        limit=top_k,
        output_fields=["id"]
    )

    output = []
    for hit in results[0]:
        entity_id = hit.id
        cur.execute("""
            SELECT v.video_path, v.title, fm.frame_idx, fm.pts_time
            FROM frame_mappings fm
            JOIN videos v ON fm.video_id = v.id
            WHERE fm.milvus_id=%s
        """, (entity_id,))
        row = cur.fetchone()
        if row:
            video_path, title, frame_idx, pts_time = row
            output.append((video_path, title, frame_idx, pts_time))

    grouped_results = {}
    for video_path, title, frame_idx, pts_time in output:
        if video_path not in grouped_results:
            grouped_results[video_path] = {"title": title, "frames": []}
        grouped_results[video_path]["frames"].append((frame_idx, pts_time))

    final_results = []
    for video_path, data in grouped_results.items():
        segments = group_timestamps(
            data["frames"],
            gap_threshold=gap_threshold,
            margin=margin,
            min_range=min_range
        )
        time_ranges = [(format_time(s), format_time(e)) for s, e, _ in segments]
        final_results.append({
            "video_path": video_path,
            "title": data["title"],
            "time_ranges": time_ranges
        })

    return final_results


import os
import pandas as pd

def keyframe_path_from_frame_idx(video_path, frame_idx, csv_dir, frame_root):
    """
    Map frame_idx -> n (theo CSV) rồi tìm file ảnh keyframe tương ứng.
    Trả về path ảnh hoặc None nếu không tìm thấy.
    """
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    group_name = "keyframes_" + video_name.split("_")[0]    # ví dụ: L24_V026 -> keyframes_L24
    csv_path   = os.path.join(csv_dir, f"{video_name}.csv")
    dir_path   = os.path.join(frame_root, group_name, video_name)

    if not os.path.exists(csv_path):
        return None
    try:
        df = pd.read_csv(csv_path)
    except Exception:
        return None

    # Cần cột 'n' và 'frame_idx'
    if not all(c in df.columns for c in ["n", "frame_idx"]):
        return None

    # Tìm hàng có frame_idx gần nhất với frame_idx yêu cầu
    idx = (df["frame_idx"] - int(frame_idx)).abs().idxmin()
    n_val = int(df.loc[idx, "n"])

    # Thử các biến thể tên file: n, zero-pad 3, zero-pad 4, và fallback theo frame_idx
    candidates = []
    for stem in [n_val, f"{n_val:03d}", f"{n_val:04d}", frame_idx, f"{int(frame_idx):03d}", f"{int(frame_idx):04d}"]:
        for ext in ("jpg", "jpeg", "png"):
            candidates.append(os.path.join(dir_path, f"{stem}.{ext}"))

    for p in candidates:
        if os.path.exists(p):
            return p
    return None

# %% [markdown]
# # querry

# %%
from deep_translator import GoogleTranslator
import os

# ---------------- Demo ----------------
# Văn bản tiếng Việt cần tìm
text_vi = "CHẢ CỐM TẠO HÌNH ÔM TRỌN VỊ NGON"
# Dịch sang tiếng Anh để match với CLIP
text_en = GoogleTranslator(source='vi', target='en').translate(text_vi)

# Tìm kiếm video dựa trên truy vấn văn bản
search_results = search_videos_by_text(text_en, top_k=20, gap_threshold=15.0)

# Chuyển đổi kết quả sang định dạng video_path -> (video_name, list of (frame_idx, time_start, time_end))
results = format_search_results(search_results, csv_dir=CSV_DIR)

# In kết quả
print(f"Kết quả tìm kiếm cho: \"{text_en}\"")
for video_path, (video_name, frames) in results.items():
    print(f"\nVideo: {video_name}")
    print(f"Path: {video_path}")

    for frame_idx, time_start, time_end in frames:
        img_path = keyframe_path_from_frame_idx(
            video_path=video_path,
            frame_idx=frame_idx,
            csv_dir=CSV_DIR,
            frame_root=FRAME_DIR
        )
        img_path_str = img_path if img_path else "⚠️ Không tìm thấy ảnh"
        print(f"Frame Idx: {frame_idx} -- Xuất hiện từ {time_start} đến {time_end} -- Path: {img_path_str}")
# Out:
# Kết quả tìm kiếm cho: "Nuggets create a delicious taste"
#
# Video: L26_V277
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V277.mp4
# Frame Idx: 5632 -- Xuất hiện từ 3:40 đến 3:52 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V277/129.jpg
#
# Video: L26_V104
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V104.mp4
# Frame Idx: 5990 -- Xuất hiện từ 3:48 đến 4:10 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V104/120.jpg
#
# Video: L26_V174
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V174.mp4
# Frame Idx: 5967 -- Xuất hiện từ 3:53 đến 4:05 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V174/140.jpg
#
# Video: L26_V310
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V310.mp4
# Frame Idx: 4224 -- Xuất hiện từ 2:44 đến 2:54 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V310/095.jpg
#
# Video: L26_V207
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V207.mp4
# Frame Idx: 6488 -- Xuất hiện từ 4:14 đến 4:26 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V207/137.jpg
# Frame Idx: 7012 -- Xuất hiện từ 4:36 đến 4:46 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V207/145.jpg
#
# Video: L26_V449
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V449.mp4
# Frame Idx: 5716 -- Xuất hiện từ 3:43 đến 3:53 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V449/124.jpg
#
# Video: L26_V226
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V226.mp4
# Frame Idx: 6272 -- Xuất hiện từ 4:06 đến 4:16 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V226/142.jpg
#
# Video: L26_V070
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V070.mp4
# Frame Idx: 6139 -- Xuất hiện từ 4:00 đến 4:10 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V070/124.jpg
#
# Video: L26_V368
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V368.mp4
# Frame Idx: 5437 -- Xuất hiện từ 3:33 đến 3:43 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V368/128.jpg
#
# Video: L26_V037
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V037.mp4
# Frame Idx: 4455 -- Xuất hiện từ 2:53 đến 3:03 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V037/096.jpg
#
# Video: L26_V416
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V416.mp4
# Frame Idx: 6275 -- Xuất hiện từ 4:06 đến 4:16 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V416/158.jpg
# Frame Idx: 6689 -- Xuất hiện từ 4:23 đến 4:33 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V416/170.jpg
#
# Video: L26_V324
# Path: /home/shared/data_batch1/Videos/videos_L26_a/L26_V324.mp4
# Frame Idx: 5888 -- Xuất hiện từ 3:51 đến 4:01 -- Path: /home/shared/data_batch1/Keyframes/keyframes_L26/L26_V324/142.jpg
